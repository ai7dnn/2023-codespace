# %%
from pandas import Series, DataFrame
import pandas as pd

# %%
myCampus = Series([200, 300, 300, 400, 500])
myCampus
# Out:
# 0    200
# 1    300
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
myCampus = Series([200, 300, 300, 400, 500], 
        index=['2023-07-25', '2023-07-26', '2023-07-27', '2023-07-28', '2023-07-29'])
myCampus
# Out:
# 2023-07-25    200
# 2023-07-26    300
# 2023-07-27    300
# 2023-07-28    400
# 2023-07-29    500
# dtype: int64

# %%
myCampus['2023-07-26']
# Out:
# 300

# %%
data = {'foreigner': [1, 2, 3, 4, 5, 6], 
        'sratio': [10, 20, 30, 40, 50, 60], 
        'org': [100, 200, 300, 400, 500, 600],
        'sprice': [1, 2, 3, 4, 5, 6],
        'private':[10, 20, 30, 40, 50, 60]}
data
# Out:
# {'foreigner': [1, 2, 3, 4, 5, 6],
#  'sratio': [10, 20, 30, 40, 50, 60],
#  'org': [100, 200, 300, 400, 500, 600],
#  'sprice': [1, 2, 3, 4, 5, 6],
#  'private': [10, 20, 30, 40, 50, 60]}

# %%
dates=['2023-07-25', '2023-07-26', '2023-07-27', '2023-07-28', '2023-07-29']

# %%
frame = DataFrame(data, 
                  columns=['private', 'org', 'foreigner', 'sratio', 'sprice'], 
                  index=['2023-07-25', '2023-07-26', '2023-07-27', '2023-07-28', '2023-07-29', '2023-07-30'])
frame
# Out:
#             private  org  foreigner  sratio  sprice
# 2023-07-25       10  100          1      10       1
# 2023-07-26       20  200          2      20       2
# 2023-07-27       30  300          3      30       3
# 2023-07-28       40  400          4      40       4
# 2023-07-29       50  500          5      50       5
# 2023-07-30       60  600          6      60       6

# %%
frame['foreigner']
# Out:
# 2023-07-25    1
# 2023-07-26    2
# 2023-07-27    3
# 2023-07-28    4
# 2023-07-29    5
# 2023-07-30    6
# Name: foreigner, dtype: int64

# %%
frame['org']
# Out:
# 2023-07-25    100
# 2023-07-26    200
# 2023-07-27    300
# 2023-07-28    400
# 2023-07-29    500
# 2023-07-30    600
# Name: org, dtype: int64

# %%
frame.T
# Out:
#            2023-07-25  2023-07-26  2023-07-27  2023-07-28  2023-07-29  \
# private            10          20          30          40          50
# org               100         200         300         400         500
# foreigner           1           2           3           4           5
# sratio             10          20          30          40          50
# sprice              1           2           3           4           5
#
#            2023-07-30
# private            60
# org               600
# foreigner           6
# sratio             60
# sprice              6

# %%
# !pwd
# Out:
# /home/a7062c47-8896-45dc-9f07-9aecfa0df1bc/my-code

# %%
import inspect

# %%
import random

# %%
inspect.getfile(random)
# Out:
# '/opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/random.py'

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.3
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# altair                        5.0.1
# anaconda-catalogs             0.2.0
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# asciitree                     0.3.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# attrs                         22.1.0
# Automat                       20.2.0
# autopep8                      1.6.0
# ...

# %%
frame1 = pd.read_csv('ex1.csv')
frame1
# Out:
#    id       name   price           description
# 0   1     iphone  890000      iphone 6s 7 8 x
# 1   2    android  990000         samsung phone
# 2   3   winphone  450000   microsoft winphone

# %%
# !ls
# Out:
# Untitled.ipynb	ex1.csv

# %%
result = pd.read_table('ex3.csv', sep='\s+')
result
# Out:
#    data1  data2  data3
# 0    1.2    2.3    1.3
# 1    0.1    1.5    2.5
# 2    3.1    3.2    3.3

# %%
frame2 = pd.read_csv('ex2.csv', names=['id', 'name', 'price', 'desc'])
frame2
# Out:
#    id       name   price                  desc
# 0   1     iphone  890000      iphone 6s 7 8 x
# 1   2    android  990000         samsung phone
# 2   3   winphone  450000   microsoft winphone

# %%
dfExcel = pd.read_excel('demo.xlsx', 'Sheet1')
dfExcel
# Out:
#      사번 성별  나이  판매금액   수입
# 0  E001  M  34   123  350
# 1  E002  F  40   114  450
# 2  E003  F  37   135  169
# 3  E004  M  30   139  189
# 4  E005  F  44   117  183
# 5  E006  M  36   121   90
# 6  E007  M  32   133  166
# 7  E008  F  26   140  120
# 8  E009  M  32   133   75
# 9  E010  M  36   133   40

# %%
import pandas as pd

# 엑셀 파일 읽기
df = pd.read_excel('전자제품_판매관리.xlsx')

# 데이터 출력
print(df)
# Out:
#          Date                     Name Prod_ID   Price  Quantity    Total
# 0  2023-01-27       trip modern recent  Prod_8  227.83         3   683.49
# 1  2023-12-03     common strategy find  Prod_8  636.43         2  1272.86
# 2  2023-11-12   quickly production arm  Prod_9  438.96         4  1755.84
# 3  2023-06-01    business decide clear  Prod_6  995.41         6  5972.46
# 4  2023-05-12  whom picture generation  Prod_7  128.34         4   513.36
# ..        ...                      ...     ...     ...       ...      ...
# 95 2023-11-09       range purpose this  Prod_3  292.29         6  1753.74
# 96 2023-01-02             baby ten way  Prod_4  699.77         6  4198.62
# 97 2023-04-24      natural fact change  Prod_2  842.13         1   842.13
# 98 2023-09-13     heavy impact involve  Prod_6  396.81         8  3174.48
# 99 2023-09-07          sound soon upon  Prod_4  395.21         2   790.42
#
# [100 rows x 6 columns]
